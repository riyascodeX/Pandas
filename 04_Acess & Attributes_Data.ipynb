# %%
import pandas as pd

# %%
#read csv data
df=pd.read_csv('data/cars.csv')
df
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 2           Plymouth Satellite  18.0        8.0         318.0       150.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...

# %% [markdown]
# # 1.DOT NOTATION

# %%
# . Noataion
df.Car
# Out:
# 0      Chevrolet Chevelle Malibu
# 1              Buick Skylark 320
# 2             Plymouth Satellite
# 3                  AMC Rebel SST
# 4                    Ford Torino
#                  ...
# 401              Ford Mustang GL
# 402            Volkswagen Pickup
# 403                Dodge Rampage
# 404                  Ford Ranger
# 405                   Chevy S-10
# Name: Car, Length: 406, dtype: str

# %% [markdown]
# # 2. BRACKET METHOD

# %%
# Bracket method
df['Car']
# Out:
# 0      Chevrolet Chevelle Malibu
# 1              Buick Skylark 320
# 2             Plymouth Satellite
# 3                  AMC Rebel SST
# 4                    Ford Torino
#                  ...
# 401              Ford Mustang GL
# 402            Volkswagen Pickup
# 403                Dodge Rampage
# 404                  Ford Ranger
# 405                   Chevy S-10
# Name: Car, Length: 406, dtype: str

# %% [markdown]
# # 2.1 BRACKET METHOD N COLUMNS

# %%
# Bracket method more than column
df[['Car','MPG']]
# Out:
#                            Car   MPG
# 0    Chevrolet Chevelle Malibu  18.0
# 1            Buick Skylark 320  15.0
# 2           Plymouth Satellite  18.0
# 3                AMC Rebel SST  16.0
# 4                  Ford Torino  17.0
# ..                         ...   ...
# 401            Ford Mustang GL  27.0
# 402          Volkswagen Pickup  44.0
# 403              Dodge Rampage  32.0
# 404                Ford Ranger  28.0
# 405                 Chevy S-10  31.0
#
# [406 rows x 2 columns]

# %% [markdown]
# # 2.2 N COLUMNS TO WRITE CSV FILE

# %%
#retrive collumn wite csv file
df[['Car','MPG']].to_csv('carsss.csv')

# %% [markdown]
# # 3. GET METHOD

# %%
# GET Method 
df.get(['Car'])
# Out:
#                            Car
# 0    Chevrolet Chevelle Malibu
# 1            Buick Skylark 320
# 2           Plymouth Satellite
# 3                AMC Rebel SST
# 4                  Ford Torino
# ..                         ...
# 401            Ford Mustang GL
# 402          Volkswagen Pickup
# 403              Dodge Rampage
# 404                Ford Ranger
# 405                 Chevy S-10
#
# [406 rows x 1 columns]

# %% [markdown]
# # 4. CHECK HOW MANY ROWS RECORDS ONLY

# %%
#index --> rows record 
df.index
# Out:
# RangeIndex(start=0, stop=406, step=1)

# %% [markdown]
# # 5. CHECK HOW MANY COLUMNS RECORDS ONLY

# %%
#column --> column record
df.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='str')

# %% [markdown]
# # 6. CHECK COLUMNS DATA TYPES

# %%
#column data types
df.dtypes
# Out:
# Car                 str
# MPG             float64
# Cylinders       float64
# Displacement    float64
# Horsepower      float64
# Weight            int64
# Acceleration    float64
# Model             int64
# Origin              str
# dtype: object

# %% [markdown]
# # 6.1 CHECK PARTICUALAR COLUMN DATA TYPE

# %%
#specific column data types
df['Car'].dtypes
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %% [markdown]
# # 7. MISSING VALUES IDENTIFIED

# %%
# Missing values detialed information like 404,405 NOT FOUND
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    str
#  1   MPG           406 non-null    float64
#  2   Cylinders     405 non-null    float64
#  3   Displacement  406 non-null    float64
#  4   Horsepower    404 non-null    float64
#  5   Weight        406 non-null    int64
#  6   Acceleration  405 non-null    float64
#  7   Model         406 non-null    int64
#  8   Origin        406 non-null    str
# dtypes: float64(5), int64(2), str(2)
# memory usage: 28.7 KB

# %% [markdown]
# # 8. RETRIVE VALUES

# %%
#Data values access
df.values
# Out:
# array([['Chevrolet Chevelle Malibu', 18.0, 8.0, ..., 12.0, 70, 'US'],
#        ['Buick Skylark 320', 15.0, 8.0, ..., 11.5, 70, 'US'],
#        ['Plymouth Satellite', 18.0, 8.0, ..., nan, 70, 'US'],
#        ...,
#        ['Dodge Rampage', 32.0, 4.0, ..., 11.6, 82, 'US'],
#        ['Ford Ranger', 28.0, 4.0, ..., 18.6, 82, 'US'],
#        ['Chevy S-10', 31.0, 4.0, ..., 19.4, 82, 'US']],
#       shape=(406, 9), dtype=object)

# %% [markdown]
# # 9. RETRIVE PARTICULAR COLUMNS VALUES

# %%
#Data values acess with particualr column
df['Car'].values
# Out:
# <StringArray>
# [ 'Chevrolet Chevelle Malibu',          'Buick Skylark 320',
#          'Plymouth Satellite',              'AMC Rebel SST',
#                 'Ford Torino',           'Ford Galaxie 500',
#            'Chevrolet Impala',          'Plymouth Fury iii',
#            'Pontiac Catalina',         'AMC Ambassador DPL',
#  ...
#  'Chrysler Lebaron Medallion',             'Ford Grenada l',
#            'Toyota Celica GT',          'Dodge Charger 2.2',
#            'Chevrolet Camaro',            'Ford Mustang GL',
#           'Volkswagen Pickup',              'Dodge Rampage',
#                 'Ford Ranger',                 'Chevy S-10']
# Length: 406, dtype: str

# %% [markdown]
# # 10. ROWS AND COLUMNS DETAILS

# %%
#range and columns name [0,1] --> acess particular data
df.axes
# Out:
# [RangeIndex(start=0, stop=406, step=1),
#  Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#         'Acceleration', 'Model', 'Origin'],
#        dtype='str')]

# %% [markdown]
# # 11.DIMENSIONAL HOW MANY ROWS AND COLUMNS

# %%
#dimensional like x axis, y axis Ex:--> a['Car].ndim=>1
df.ndim
# Out:
# 2

# %% [markdown]
# # 12. ROWS X COLUMNS

# %%
# rows X colum -- 409 x 9
df.size
# Out:
# 3654

# %% [markdown]
# # 13. ROWS & COLUMNS

# %%
#How many rows and columns  Ex:---> a.shape[0,1]
df.shape
# Out:
# (406, 9)

# %% [markdown]
# # 14. MEMORY OCCUPIED CHECK

# %%
# memeory_usage -->overall occupied data , (deep=True)-->Exact occupied data
df.memory_usage(deep=True)
# Out:
# Index             132
# Car             26526
# MPG              3248
# Cylinders        3248
# Displacement     3248
# Horsepower       3248
# Weight           3248
# Acceleration     3248
# Model            3248
# Origin          21235
# dtype: int64

# %% [markdown]
# # 15. FIRST 4 DATA

# %%
#first 4 rows , customize -->a.head(28)
df.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1          Buick Skylark 320  15.0        8.0         350.0       165.0
# 2         Plymouth Satellite  18.0        8.0         318.0       150.0
# 3              AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                Ford Torino  17.0        8.0         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436           NaN     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %% [markdown]
# # 15.1 LASR 4 DATA

# %%
#last four rows , customize --> a.tail(30)
df.tail()
# Out:
#                    Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 401    Ford Mustang GL  27.0        4.0         140.0        86.0    2790
# 402  Volkswagen Pickup  44.0        4.0          97.0        52.0    2130
# 403      Dodge Rampage  32.0        4.0         135.0        84.0    2295
# 404        Ford Ranger  28.0        4.0         120.0        79.0    2625
# 405         Chevy S-10  31.0        4.0         119.0        82.0    2720
#
#      Acceleration  Model  Origin
# 401          15.6     82      US
# 402          24.6     82  Europe
# 403          11.6     82      US
# 404          18.6     82      US
# 405          19.4     82      US
