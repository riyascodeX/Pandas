# %%
import pandas as pd

# %% [markdown]
# #-----------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # CREATE DATARAME

# %%
df=pd.DataFrame(
    {
        'Name':['riyas','sameer','vajith','sarbu','rijas'],
        'Age':[20,20,25,24,21],
        'work':['Analytics Engineer','Store Manager','Technical Support','Product Manager','Video Editor']
    }
)
df
# Out:
#      Name  Age                work
# 0   riyas   20  Analytics Engineer
# 1  sameer   20       Store Manager
# 2  vajith   25   Technical Support
# 3   sarbu   24     Product Manager
# 4   rijas   21        Video Editor

# %% [markdown]
# #-----------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 1. COPY DATAFRAME

# %%
df2=df.copy()
df2
# Out:
#      Name  Age                work
# 0   riyas   20  Analytics Engineer
# 1  sameer   20       Store Manager
# 2  vajith   25   Technical Support
# 3   sarbu   24     Product Manager
# 4   rijas   21        Video Editor

# %% [markdown]
# # 1.2 CHANGE COPY COLUMNS

# %%
df2.columns=['person','old','profess']
df2
# Out:
#    person  old             profess
# 0   riyas   20  Analytics Engineer
# 1  sameer   20       Store Manager
# 2  vajith   25   Technical Support
# 3   sarbu   24     Product Manager
# 4   rijas   21        Video Editor

# %% [markdown]
# # 1.3 CHECK CHANGES IN ORIGINAL

# %%
df
# Out:
#      Name  Age                work
# 0   riyas   20  Analytics Engineer
# 1  sameer   20       Store Manager
# 2  vajith   25   Technical Support
# 3   sarbu   24     Product Manager
# 4   rijas   21        Video Editor

# %% [markdown]
# #-----------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 2. REFERANCE DATAFRAME

# %%
df_ref = df

# %% [markdown]
# # 2.1 CHANGE REFERANCE COLUMNS

# %%
df_ref.columns=['person','old','profess']
df_ref
# Out:
#    person  old             profess
# 0   riyas   20  Analytics Engineer
# 1  sameer   20       Store Manager
# 2  vajith   25   Technical Support
# 3   sarbu   24     Product Manager
# 4   rijas   21        Video Editor

# %% [markdown]
# # 2.2 CHECK CHANGES IN ORIGINAL

# %%
df
# Out:
#    person  old             profess
# 0   riyas   20  Analytics Engineer
# 1  sameer   20       Store Manager
# 2  vajith   25   Technical Support
# 3   sarbu   24     Product Manager
# 4   rijas   21        Video Editor

# %% [markdown]
# #-----------------------------------------------------------------------------------------------------------------------------------------------
