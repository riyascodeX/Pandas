# %%
import pandas as pd

# %%
df=pd.read_csv('dataset/Cars.csv')
df
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 2           Plymouth Satellite  18.0        8.0         318.0       150.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...

# %% [markdown]
# # 1.SET [CAR] COLUMNS INDEX

# %%
df.set_index('Car')
# Out:
#                             MPG  Cylinders  Displacement  Horsepower  Weight  \
# Car
# Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0    3504
# Buick Skylark 320          15.0        8.0         350.0       165.0    3693
# Plymouth Satellite         18.0        8.0         318.0       150.0    3436
# AMC Rebel SST              16.0        8.0         304.0       150.0    3433
# Ford Torino                17.0        8.0         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# Ford Mustang GL            27.0        4.0         140.0        86.0    2790
# Volkswagen Pickup          44.0        4.0          97.0        52.0    2130
# Dodge Rampage              32.0        4.0         135.0        84.0    2295
# Ford Ranger                28.0        4.0         120.0        79.0    2625
# Chevy S-10                 31.0        4.0         119.0        82.0    2720
#
# ...

# %% [markdown]
# # 2. CUSTOM COLUMN ORDER CHANGE

# %%
df.reindex(columns=['Origin','Car','Horsepower'])
# Out:
#      Origin                        Car  Horsepower
# 0        US  Chevrolet Chevelle Malibu       130.0
# 1        US          Buick Skylark 320       165.0
# 2        US         Plymouth Satellite       150.0
# 3        US              AMC Rebel SST       150.0
# 4        US                Ford Torino       140.0
# ..      ...                        ...         ...
# 401      US            Ford Mustang GL        86.0
# 402  Europe          Volkswagen Pickup        52.0
# 403      US              Dodge Rampage        84.0
# 404      US                Ford Ranger        79.0
# 405      US                 Chevy S-10        82.0
#
# [406 rows x 3 columns]

# %% [markdown]
# # 2.1 CUSTOM INDEX ORDER CHANGE

# %%
df.reindex([1,3,5])
# Out:
#                  Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 1  Buick Skylark 320  15.0        8.0         350.0       165.0    3693
# 3      AMC Rebel SST  16.0        8.0         304.0       150.0    3433
# 5   Ford Galaxie 500  15.0        8.0         429.0       198.0    4341
#
#    Acceleration  Model Origin
# 1          11.5     70     US
# 3          12.0     70     US
# 5          10.0     70     US

# %% [markdown]
# # 2.2 CUSTOM INDEX ORDER CHANGE IN SET INDEX

# %%
#  RULE ---> SET COLUMN INDEX THEN REINDEX INDEX COLUMN
df.reindex(['Chevy S-10', 'Ford Ranger'])
# Out:
#              Car  MPG  Cylinders  Displacement  Horsepower  Weight  \
# Chevy S-10   NaN  NaN        NaN           NaN         NaN     NaN
# Ford Ranger  NaN  NaN        NaN           NaN         NaN     NaN
#
#              Acceleration  Model Origin
# Chevy S-10            NaN    NaN    NaN
# Ford Ranger           NaN    NaN    NaN

# %% [markdown]
# # 3.ORDER CHANGED COLUMN OR INDEX SET (NEW INDEX)

# %%
df.reset_index()
df.reset_index(drop=True)
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 2           Plymouth Satellite  18.0        8.0         318.0       150.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...
