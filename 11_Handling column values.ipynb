# %%
import pandas as pd

# %%
df=pd.read_csv('Dataset/cars.csv')
df
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 2           Plymouth Satellite  18.0        8.0         318.0       150.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...

# %% [markdown]
# ## REMEMBER COLON [ : ] MAIN

# %% [markdown]
# # 1. GET COLUMN VALUES

# %%
# GET COLUMN VALUES
df.loc[:,'Car']
# Out:
# 0      Chevrolet Chevelle Malibu
# 1              Buick Skylark 320
# 2             Plymouth Satellite
# 3                  AMC Rebel SST
# 4                    Ford Torino
#                  ...
# 401              Ford Mustang GL
# 402            Volkswagen Pickup
# 403                Dodge Rampage
# 404                  Ford Ranger
# 405                   Chevy S-10
# Name: Car, Length: 406, dtype: str

# %% [markdown]
# # 1.1 SET COLUMN VALUES

# %%
# SET COLUMN VALUES
df.loc[:,'Car']='column changed'

# %% [markdown]
# # 1.2 CHECK [CAR] COLUMN CHANGES

# %%
df
# Out:
#                 Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 0    column changed  18.0        8.0         307.0       130.0    3504
# 1    column changed  15.0        8.0         350.0       165.0    3693
# 2    column changed  18.0        8.0         318.0       150.0    3436
# 3    column changed  16.0        8.0         304.0       150.0    3433
# 4    column changed  17.0        8.0         302.0       140.0    3449
# ..              ...   ...        ...           ...         ...     ...
# 401  column changed  27.0        4.0         140.0        86.0    2790
# 402  column changed  44.0        4.0          97.0        52.0    2130
# 403  column changed  32.0        4.0         135.0        84.0    2295
# 404  column changed  28.0        4.0         120.0        79.0    2625
# 405  column changed  31.0        4.0         119.0        82.0    2720
#
#      Acceleration  Model  Origin
# 0            12.0     70      US
# 1            11.5     70      US
# ...

# %% [markdown]
# # 2. GET COLUMN VALUES IN RANGE

# %%
# GET COLUMN RANGE
df.loc[:,'Car':'Cylinders']
# Out:
#                            Car   MPG  Cylinders
# 0    Chevrolet Chevelle Malibu  18.0        8.0
# 1            Buick Skylark 320  15.0        8.0
# 2           Plymouth Satellite  18.0        8.0
# 3                AMC Rebel SST  16.0        8.0
# 4                  Ford Torino  17.0        8.0
# ..                         ...   ...        ...
# 401            Ford Mustang GL  27.0        4.0
# 402          Volkswagen Pickup  44.0        4.0
# 403              Dodge Rampage  32.0        4.0
# 404                Ford Ranger  28.0        4.0
# 405                 Chevy S-10  31.0        4.0
#
# [406 rows x 3 columns]

# %% [markdown]
# # 2.2 SET COLUMN VALUES IN RANGE

# %%
# SET COLUMN RANGE VALUES
df.loc[:,'Car':'Cylinders']=['range_column_changed',0.0,0.0]

# %% [markdown]
# # 2.3 CHECK [CAR,MPG,CYCLINDERS] COLUMN CHANGES

# %%
df
# Out:
#                       Car  MPG  Cylinders  Displacement  Horsepower  Weight  \
# 0    range_column_changed  0.0        0.0         307.0       130.0    3504
# 1    range_column_changed  0.0        0.0         350.0       165.0    3693
# 2    range_column_changed  0.0        0.0         318.0       150.0    3436
# 3    range_column_changed  0.0        0.0         304.0       150.0    3433
# 4    range_column_changed  0.0        0.0         302.0       140.0    3449
# ..                    ...  ...        ...           ...         ...     ...
# 401  range_column_changed  0.0        0.0         140.0        86.0    2790
# 402  range_column_changed  0.0        0.0          97.0        52.0    2130
# 403  range_column_changed  0.0        0.0         135.0        84.0    2295
# 404  range_column_changed  0.0        0.0         120.0        79.0    2625
# 405  range_column_changed  0.0        0.0         119.0        82.0    2720
#
#      Acceleration  Model  Origin
# ...

# %% [markdown]
# # 3. GET INTERMITTENT COLUMN VALUES

# %%
# GET INTERMITENT COLUMN
df.loc[:,['Model','Origin']]
# Out:
#      Model  Origin
# 0       70      US
# 1       70      US
# 2       70      US
# 3       70      US
# 4       70      US
# ..     ...     ...
# 401     82      US
# 402     82  Europe
# 403     82      US
# 404     82      US
# 405     82      US
#
# [406 rows x 2 columns]

# %% [markdown]
# # 3.1 SET INTERMITENT COLUMN VALUES

# %%
# SET INTERMITENT COLUMN VALUES
df.loc[:,['Model','Origin']]=[100,'intermitent']

# %% [markdown]
# # 3.2 CHECK INTERMITTENT COLUMN CHANGES

# %%
df
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 2           Plymouth Satellite  18.0        8.0         318.0       150.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model       Origin
# ...
