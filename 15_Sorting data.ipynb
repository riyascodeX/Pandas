# %%
import pandas as pd

# %%
a=pd.read_csv('data/cars.csv')
a
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0        8.0         307.0       130.0
# 1            Buick Skylark 320  15.0        8.0         350.0       165.0
# 2           Plymouth Satellite  18.0        8.0         318.0       150.0
# 3                AMC Rebel SST  16.0        8.0         304.0       150.0
# 4                  Ford Torino  17.0        8.0         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0        4.0         140.0        86.0
# 402          Volkswagen Pickup  44.0        4.0          97.0        52.0
# 403              Dodge Rampage  32.0        4.0         135.0        84.0
# 404                Ford Ranger  28.0        4.0         120.0        79.0
# 405                 Chevy S-10  31.0        4.0         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...

# %%
a.sort_values(by=)

# %% [markdown]
# # sysntax : sort_values( by=column_name , asc=true|false , na_position= first|last)

# %%
a.sort_values(by='Car')
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 103  AMC Ambassador Brougham  13.0        8.0         360.0       175.0
# 9         AMC Ambassador DPL  15.0        8.0         390.0       190.0
# 73        AMC Ambassador SST  17.0        8.0         304.0       150.0
# 264              AMC Concord  19.4        6.0         232.0        90.0
# 322              AMC Concord  24.3        4.0         151.0        90.0
# ..                       ...   ...        ...           ...         ...
# 83           Volvo 145e (sw)  18.0        4.0         121.0       112.0
# 186              Volvo 244DL  22.0        4.0         121.0        98.0
# 214                Volvo 245  20.0        4.0         130.0       102.0
# 282              Volvo 264gl  17.0        6.0         163.0       125.0
# 368             Volvo Diesel  30.7        6.0         145.0        76.0
#
#      Weight  Acceleration  Model  Origin
# 103    3821          11.0     73      US
# ...

# %%
a.sort_values(by='Cylinders',ascending=False)
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 372    Oldsmobile Cutlass LS  26.6        8.0         350.0       105.0
# 32                 Chevy C20  10.0        8.0         307.0       200.0
# 31                 Ford F250  10.0        8.0         360.0       215.0
# 19   Buick Estate Wagon (sw)  14.0        8.0         455.0       225.0
# 18     Chevrolet Monte Carlo  15.0        8.0         400.0       150.0
# ..                       ...   ...        ...           ...         ...
# 341            Mazda RX-7 GS  23.7        3.0          70.0       100.0
# 250               Mazda RX-4  21.5        3.0          80.0       110.0
# 78           Mazda RX2 Coupe  19.0        3.0          70.0        97.0
# 118                Mazda RX3  18.0        3.0          70.0        90.0
# 7          Plymouth Fury iii  14.0        NaN         440.0       215.0
#
#      Weight  Acceleration  Model Origin
# 372    3725          19.0     81     US
# ...

# %%
a.sort_values(by='Acceleration',ascending=False,na_position='first')
# Out:
#                             Car   MPG  Cylinders  Displacement  Horsepower  \
# 2            Plymouth Satellite  18.0        8.0         318.0       150.0
# 306                 Peugeot 504  27.2        4.0         141.0        71.0
# 402           Volkswagen Pickup  44.0        4.0          97.0        52.0
# 333  Volkswagen Dasher (diesel)  43.4        4.0          90.0        48.0
# 66            Volkswagen Type 3  23.0        4.0          97.0        54.0
# ..                          ...   ...        ...           ...         ...
# 6              Chevrolet Impala  14.0        8.0         454.0       220.0
# 9            AMC Ambassador DPL  15.0        8.0         390.0       190.0
# 7             Plymouth Fury iii  14.0        NaN         440.0       215.0
# 17        Ford Mustang Boss 302   0.0        8.0         302.0       140.0
# 16           Plymouth 'Cuda 340  14.0        8.0         340.0       160.0
#
#      Weight  Acceleration  Model  Origin
# ...
