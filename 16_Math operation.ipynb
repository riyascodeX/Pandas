# %%
import pandas as pd

# %%
values={
    'A':[5,10,15,20],
    'B':[2,4,6,8],
    'C':[1,3,5,7]
}

df=pd.DataFrame(values)
df
# Out:
#     A  B  C
# 0   5  2  1
# 1  10  4  3
# 2  15  6  5
# 3  20  8  7

# %%
# Addition
df.add(10)
# Out:
#     A   B   C
# 0  15  12  11
# 1  20  14  13
# 2  25  16  15
# 3  30  18  17

# %%
# Subtraction
df.sub(1)
# Out:
#     A  B  C
# 0   4  1  0
# 1   9  3  2
# 2  14  5  4
# 3  19  7  6

# %%
# Subtraction
df.subtract(1)
# Out:
#     A  B  C
# 0   4  1  0
# 1   9  3  2
# 2  14  5  4
# 3  19  7  6

# %%
# Multiplication
df.mul(2)
# Out:
#     A   B   C
# 0  10   4   2
# 1  20   8   6
# 2  30  12  10
# 3  40  16  14

# %%
# Multiplication
df.mul(2)
# Out:
#     A   B   C
# 0  10   4   2
# 1  20   8   6
# 2  30  12  10
# 3  40  16  14

# %%
# Division
df.div(2)
# Out:
#       A    B    C
# 0   2.5  1.0  0.5
# 1   5.0  2.0  1.5
# 2   7.5  3.0  2.5
# 3  10.0  4.0  3.5

# %%
# Division
df.divide(2)
# Out:
#       A    B    C
# 0   2.5  1.0  0.5
# 1   5.0  2.0  1.5
# 2   7.5  3.0  2.5
# 3  10.0  4.0  3.5

# %%
# Floor Division
df.floordiv(2)
# Out:
#     A  B  C
# 0   2  1  0
# 1   5  2  1
# 2   7  3  2
# 3  10  4  3

# %%
df
# Out:
#     A  B  C
# 0   5  2  1
# 1  10  4  3
# 2  15  6  5
# 3  20  8  7

# %%
# Modulus
df.mod(2)
# Out:
#    A  B  C
# 0  1  0  1
# 1  0  0  1
# 2  1  0  1
# 3  0  0  1

# %%
# Power
df.pow(2)
# Out:
#      A   B   C
# 0   25   4   1
# 1  100  16   9
# 2  225  36  25
# 3  400  64  49

# %% [markdown]
# # .Dot method

# %%
a=pd.DataFrame(
    {
    'A':[1,2],
    'B':[4,5]
    }
)

# %%
a
# Out:
#    A  B
# 0  1  4
# 1  2  5

# %%
b=pd.DataFrame(
    {
    'A':[1,2,3],
    'B':[4,5,6]
    }
)

# %%
b
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
a.dot(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 a.dot(b)
#
# File c:\Users\riyas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1765, in DataFrame.dot(self, other)
#    1761         """
#    1762         if isinstance(other, (Series, DataFrame)):
#    1763             common = self.columns.union(other.index)
#    1764             if len(common) > len(self.columns) or len(common) > len(other.index):
# -> 1765                 raise ValueError("matrices are not aligned")
#    1766
#    1767             left = self.reindex(columns=common)
#    1768             right = other.reindex(index=common)
#
# ValueError: matrices are not aligned
