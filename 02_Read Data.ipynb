# %%
import pandas as pd

# %% [markdown]
# #-----------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 1.CLIPBOARD

# %%
# clipbord read
df=pd.read_clipboard()
df
# Out:
#      0 Chevrolet Chevelle Malibu  18.0  8.0  307.0  130.0  3504  12.0   70  \
# 0    1         Buick Skylark 320  15.0  8.0  350.0  165.0  3693  11.5   70
# 1    2        Plymouth Satellite  18.0  8.0  318.0  150.0  3436   NaN   70
# 2    3             AMC Rebel SST  16.0  8.0  304.0  150.0  3433  12.0   70
# 3    4               Ford Torino  17.0  8.0  302.0  140.0  3449  10.5   70
# 4  ...                       ...   ...  ...    ...    ...   ...   ...  ...
# 5  401           Ford Mustang GL  27.0  4.0  140.0   86.0  2790  15.6   82
# 6  402         Volkswagen Pickup  44.0  4.0   97.0   52.0  2130  24.6   82
# 7  403             Dodge Rampage  32.0  4.0  135.0   84.0  2295  11.6   82
# 8  404               Ford Ranger  28.0  4.0  120.0   79.0  2625  18.6   82
# 9  405                Chevy S-10  31.0  4.0  119.0   82.0  2720  19.4   82
#
#        US
# 0      US
# 1      US
# 2      US
# 3      US
# 4     ...
# 5      US
# 6  Europe
# 7      US
# 8      US
# 9      US

# %% [markdown]
# #-----------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 2.READ EXCEL FILE

# %%
# read excel file must install package in openpyxl
# !pip install openpyxl
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
#read excel file and choose header
df=pd.read_excel('data/cars.xlsx',header=1)
df
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu      18         8          307        130
# 2            Buick Skylark 320      15         8          350        165
# 3           Plymouth Satellite      18         8          318        150
# 4                AMC Rebel SST      16         8          304        150
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL      27         4          140         86
# 403          Volkswagen Pickup      44         4           97         52
# 404              Dodge Rampage      32         4          135         84
# 405                Ford Ranger      28         4          120         79
# 406                 Chevy S-10      31         4          119         82
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
# sheetname change
df=pd.read_excel('data/cars.xlsx',header=1,sheet_name='Summary')
df
# Out:
#                  Car  MPG  Cylinders  Displacement  Horsepower  Weight  \
# 0         Ford Pinto   18          6           171          97    2984
# 1  Volkswagen Rabbit   29          4            90          70    1937
# 2          AMC Pacer   19          6           232          90    3211
# 3         Audi 100LS   23          4           115          95    2694
# 4        Peugeot 504   23          4           120          88    2957
# 5        Volvo 244DL   22          4           121          98    2945
# 6          Saab 99LE   25          4           121         115    2671
# 7   Honda Civic CVCC   33          4            91          53    1795
# 8           Fiat 131   28          4           107          86    2464
#
#    Acceleration  Model  Origin
# 0          14.5     75      US
# 1          14.0     75  Europe
# 2          17.0     75      US
# 3          15.0     75  Europe
# 4          17.0     75  Europe
# 5          14.5     75  Europe
# 6          13.5     75  Europe
# ...

# %% [markdown]
# #-----------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 3. READ JSON FILE

# %%
#read json file
df=pd.read_json('data/cars.json')
df
# Out:
#                     Car     MPG Cylinders Displacement Horsepower  Weight  \
# 0                STRING  DOUBLE       INT       DOUBLE     DOUBLE  DOUBLE
# 1                 riyas      18         8          307        130    3504
# 2     Buick Skylark 320      15         8          350        165    3693
# 3    Plymouth Satellite      18         8          318        150    3436
# 4         AMC Rebel SST      16         8          304        150    3433
# ..                  ...     ...       ...          ...        ...     ...
# 402     Ford Mustang GL      27         4          140         86    2790
# 403   Volkswagen Pickup      44         4           97         52    2130
# 404       Dodge Rampage      32         4          135         84    2295
# 405         Ford Ranger      28         4          120         79    2625
# 406          Chevy S-10      31         4          119         82    2720
#
#     Acceleration Model  Origin
# 0         DOUBLE   INT     CAT
# ...

# %% [markdown]
# #-----------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 4. READ PICKLE FILE

# %%
#read pickle file
df=pd.read_pickle('data/cars.pk')
df
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu      18         8          307        130
# 2            Buick Skylark 320      15         8          350        165
# 3           Plymouth Satellite      18         8          318        150
# 4                AMC Rebel SST      16         8          304        150
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL      27         4          140         86
# 403          Volkswagen Pickup      44         4           97         52
# 404              Dodge Rampage      32         4          135         84
# 405                Ford Ranger      28         4          120         79
# 406                 Chevy S-10      31         4          119         82
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %% [markdown]
# #-----------------------------------------------------------------------------------------------------------------------------------------------
